# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import os
import glob

# %%
epochs = 100
lr = 1e-3
batch_size = 64
img_dims = (96, 96, 3)

data = []
labels = []

# %%
image_files = [f for f in glob.glob(r'.\gender_dataset_face' + "/**/*", recursive=True) if not os.path.isdir(f)]
random.shuffle(image_files)

# converting images to arrays and labeling the categories
for img in image_files:
    image = cv2.imread(img)
    image = cv2.resize(image, (img_dims[0], img_dims[1]))
    image = img_to_array(image)
    data.append(image)

    label = img.split(os.path.sep)[-2]  # C:\Files\gender_dataset_face\woman\face_1162.jpg
    label = 1 if label == "woman" else 0
    labels.append(label)

# %%
# pre-processing
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
# split dataset for training and validation
trainX, testX, trainY, testY = train_test_split(data, labels, test_size=0.2, random_state=42)

trainY = to_categorical(trainY, num_classes=2)  # [[1, 0], [0, 1], [0, 1], ...]
testY = to_categorical(testY, num_classes=2)

# %%
# augmenting dataset
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# %%
# define model
def build(width, height, depth, classes):
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1

    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1

    model.add(Conv2D(32, (3, 3), padding="same", input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(classes))
    model.add(Activation("sigmoid"))

    return model

# %%
# build model
model = build(width=img_dims[0], height=img_dims[1], depth=img_dims[2], classes=2)

# compile the model
opt = Adam(learning_rate=lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# calculate the steps per epoch
steps_per_epoch = len(trainX) // batch_size

# train the model
H = model.fit(aug.flow(trainX, trainY, batch_size=batch_size),
              validation_data=(testX, testY),
              steps_per_epoch=steps_per_epoch,
              epochs=epochs, verbose=1)
# Out:
# C:\Users\okays\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# C:\Users\okays\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 26s 739ms/step - accuracy: 0.6601 - loss: 0.9138 - val_accuracy: 0.5390 - val_loss: 0.6801
# Epoch 2/100
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 17s 634ms/step - accuracy: 0.8594 - loss: 0.5426
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1520.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8594 - loss: 0.5426 - val_accuracy: 0.5173 - val_loss: 0.6920
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 659ms/step - accuracy: 0.8107 - loss: 0.4947 - val_accuracy: 0.4827 - val_loss: 0.8476
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8438 - loss: 0.3336 - val_accuracy: 0.4827 - val_loss: 0.8988
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 656ms/step - accuracy: 0.8366 - loss: 0.4076 - val_accuracy: 0.4827 - val_loss: 1.1814
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8438 - loss: 0.4667 - val_accuracy: 0.4827 - val_loss: 1.0938
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 655ms/step - accuracy: 0.8635 - loss: 0.3269 - val_accuracy: 0.4827 - val_loss: 1.5629
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8750 - loss: 0.2966 - val_accuracy: 0.4827 - val_loss: 1.5265
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 652ms/step - accuracy: 0.8704 - loss: 0.3490 - val_accuracy: 0.4827 - val_loss: 1.2441
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9062 - loss: 0.2486 - val_accuracy: 0.4827 - val_loss: 1.1926
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 650ms/step - accuracy: 0.8893 - loss: 0.2984 - val_accuracy: 0.4827 - val_loss: 2.1064
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9062 - loss: 0.3102 - val_accuracy: 0.4827 - val_loss: 2.1282
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 653ms/step - accuracy: 0.8731 - loss: 0.3112 - val_accuracy: 0.5195 - val_loss: 0.7653
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8281 - loss: 0.4194 - val_accuracy: 0.5693 - val_loss: 0.7228
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 652ms/step - accuracy: 0.8949 - loss: 0.2721 - val_accuracy: 0.4827 - val_loss: 2.0910
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9219 - loss: 0.1858 - val_accuracy: 0.4827 - val_loss: 2.1168
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 654ms/step - accuracy: 0.9217 - loss: 0.2349 - val_accuracy: 0.4827 - val_loss: 1.3290
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9057 - loss: 0.2490 - val_accuracy: 0.4848 - val_loss: 1.2920
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 662ms/step - accuracy: 0.9259 - loss: 0.2075 - val_accuracy: 0.6429 - val_loss: 0.6323
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9375 - loss: 0.2206 - val_accuracy: 0.6991 - val_loss: 0.5584
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 653ms/step - accuracy: 0.9157 - loss: 0.2124 - val_accuracy: 0.7965 - val_loss: 0.4590
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9062 - loss: 0.1696 - val_accuracy: 0.7857 - val_loss: 0.4636
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 650ms/step - accuracy: 0.9370 - loss: 0.1645 - val_accuracy: 0.8139 - val_loss: 0.3731
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8906 - loss: 0.2247 - val_accuracy: 0.7749 - val_loss: 0.4665
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 653ms/step - accuracy: 0.9300 - loss: 0.1796 - val_accuracy: 0.7338 - val_loss: 0.5891
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9688 - loss: 0.1202 - val_accuracy: 0.7143 - val_loss: 0.6371
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 735ms/step - accuracy: 0.9381 - loss: 0.1752 - val_accuracy: 0.7965 - val_loss: 0.4426
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9531 - loss: 0.1208 - val_accuracy: 0.8095 - val_loss: 0.4178
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 786ms/step - accuracy: 0.9390 - loss: 0.1790 - val_accuracy: 0.7013 - val_loss: 0.8072
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9844 - loss: 0.0578 - val_accuracy: 0.6667 - val_loss: 0.9387
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 754ms/step - accuracy: 0.9541 - loss: 0.1206 - val_accuracy: 0.8853 - val_loss: 0.3157
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9844 - loss: 0.1092 - val_accuracy: 0.8896 - val_loss: 0.3097
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 840ms/step - accuracy: 0.9494 - loss: 0.1384 - val_accuracy: 0.8615 - val_loss: 0.3263
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9531 - loss: 0.0885 - val_accuracy: 0.8355 - val_loss: 0.3946
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 25s 855ms/step - accuracy: 0.9399 - loss: 0.1531 - val_accuracy: 0.9307 - val_loss: 0.1939
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8906 - loss: 0.2515 - val_accuracy: 0.9286 - val_loss: 0.1879
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 740ms/step - accuracy: 0.9430 - loss: 0.1554 - val_accuracy: 0.9437 - val_loss: 0.1449
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9531 - loss: 0.1774 - val_accuracy: 0.9437 - val_loss: 0.1443
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 795ms/step - accuracy: 0.9477 - loss: 0.1210 - val_accuracy: 0.8506 - val_loss: 0.4079
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9375 - loss: 0.1863 - val_accuracy: 0.8355 - val_loss: 0.4623
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 780ms/step - accuracy: 0.9600 - loss: 0.1071 - val_accuracy: 0.9307 - val_loss: 0.1698
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9062 - loss: 0.1973 - val_accuracy: 0.9351 - val_loss: 0.1670
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 802ms/step - accuracy: 0.9579 - loss: 0.1122 - val_accuracy: 0.9524 - val_loss: 0.1449
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9531 - loss: 0.1094 - val_accuracy: 0.9545 - val_loss: 0.1193
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 784ms/step - accuracy: 0.9576 - loss: 0.0982 - val_accuracy: 0.8658 - val_loss: 0.4654
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9688 - loss: 0.0841 - val_accuracy: 0.8745 - val_loss: 0.4517
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 783ms/step - accuracy: 0.9687 - loss: 0.0932 - val_accuracy: 0.9416 - val_loss: 0.1471
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9531 - loss: 0.1444 - val_accuracy: 0.9437 - val_loss: 0.1384
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 819ms/step - accuracy: 0.9579 - loss: 0.1049 - val_accuracy: 0.9286 - val_loss: 0.2190
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9531 - loss: 0.1171 - val_accuracy: 0.9177 - val_loss: 0.2619
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 822ms/step - accuracy: 0.9583 - loss: 0.1014 - val_accuracy: 0.8506 - val_loss: 1.1986
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9811 - loss: 0.1439 - val_accuracy: 0.8636 - val_loss: 0.9157
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 773ms/step - accuracy: 0.9586 - loss: 0.1089 - val_accuracy: 0.9177 - val_loss: 0.4549
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9688 - loss: 0.0544 - val_accuracy: 0.9199 - val_loss: 0.4176
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 775ms/step - accuracy: 0.9618 - loss: 0.1064 - val_accuracy: 0.9351 - val_loss: 0.2585
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8906 - loss: 0.2386 - val_accuracy: 0.9437 - val_loss: 0.1938
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 777ms/step - accuracy: 0.9729 - loss: 0.0824 - val_accuracy: 0.9502 - val_loss: 0.1141
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9219 - loss: 0.2521 - val_accuracy: 0.9416 - val_loss: 0.1467
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 778ms/step - accuracy: 0.9566 - loss: 0.1168 - val_accuracy: 0.7684 - val_loss: 0.8407
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9688 - loss: 0.0520 - val_accuracy: 0.7792 - val_loss: 0.8129
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 774ms/step - accuracy: 0.9560 - loss: 0.1094 - val_accuracy: 0.9481 - val_loss: 0.1507
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9219 - loss: 0.1523 - val_accuracy: 0.9545 - val_loss: 0.1364
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 774ms/step - accuracy: 0.9590 - loss: 0.1051 - val_accuracy: 0.9545 - val_loss: 0.1240
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9531 - loss: 0.0958 - val_accuracy: 0.9545 - val_loss: 0.1281
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 772ms/step - accuracy: 0.9645 - loss: 0.0934 - val_accuracy: 0.9437 - val_loss: 0.1941
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9688 - loss: 0.1454 - val_accuracy: 0.9459 - val_loss: 0.1813
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 770ms/step - accuracy: 0.9690 - loss: 0.0811 - val_accuracy: 0.9329 - val_loss: 0.2062
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9688 - loss: 0.1126 - val_accuracy: 0.9242 - val_loss: 0.2381
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 768ms/step - accuracy: 0.9718 - loss: 0.0759 - val_accuracy: 0.9199 - val_loss: 0.2749
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9531 - loss: 0.1019 - val_accuracy: 0.9134 - val_loss: 0.3008
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 777ms/step - accuracy: 0.9667 - loss: 0.0800 - val_accuracy: 0.9459 - val_loss: 0.1605
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9531 - loss: 0.0979 - val_accuracy: 0.9545 - val_loss: 0.1626
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 778ms/step - accuracy: 0.9708 - loss: 0.0763 - val_accuracy: 0.9481 - val_loss: 0.2294
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9844 - loss: 0.0259 - val_accuracy: 0.9437 - val_loss: 0.2284
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 795ms/step - accuracy: 0.9718 - loss: 0.0739 - val_accuracy: 0.9632 - val_loss: 0.1204
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9062 - loss: 0.1693 - val_accuracy: 0.9654 - val_loss: 0.1196
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 829ms/step - accuracy: 0.9704 - loss: 0.0825 - val_accuracy: 0.9502 - val_loss: 0.1432
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9688 - loss: 0.0686 - val_accuracy: 0.9610 - val_loss: 0.1199
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 823ms/step - accuracy: 0.9799 - loss: 0.0582 - val_accuracy: 0.9481 - val_loss: 0.2454
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9688 - loss: 0.0815 - val_accuracy: 0.9481 - val_loss: 0.2237
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 822ms/step - accuracy: 0.9678 - loss: 0.0760 - val_accuracy: 0.9199 - val_loss: 0.1978
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9688 - loss: 0.0477 - val_accuracy: 0.8983 - val_loss: 0.2871
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 826ms/step - accuracy: 0.9754 - loss: 0.0578 - val_accuracy: 0.9502 - val_loss: 0.1681
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9375 - loss: 0.1332 - val_accuracy: 0.9589 - val_loss: 0.1058
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 822ms/step - accuracy: 0.9760 - loss: 0.0648 - val_accuracy: 0.7511 - val_loss: 1.1505
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9844 - loss: 0.0559 - val_accuracy: 0.7771 - val_loss: 1.0053
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 815ms/step - accuracy: 0.9822 - loss: 0.0545 - val_accuracy: 0.8420 - val_loss: 0.6132
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.8983 - val_loss: 0.3700
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 810ms/step - accuracy: 0.9652 - loss: 0.0936 - val_accuracy: 0.8615 - val_loss: 0.4489
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9688 - loss: 0.0573 - val_accuracy: 0.8701 - val_loss: 0.4385
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 773ms/step - accuracy: 0.9610 - loss: 0.0895 - val_accuracy: 0.9784 - val_loss: 0.0834
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9375 - loss: 0.1488 - val_accuracy: 0.9762 - val_loss: 0.0788
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 780ms/step - accuracy: 0.9758 - loss: 0.0805 - val_accuracy: 0.9632 - val_loss: 0.0969
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9623 - loss: 0.0556 - val_accuracy: 0.9545 - val_loss: 0.1527
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 778ms/step - accuracy: 0.9756 - loss: 0.0645 - val_accuracy: 0.9416 - val_loss: 0.2160
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9844 - loss: 0.0281 - val_accuracy: 0.9394 - val_loss: 0.2010
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 778ms/step - accuracy: 0.9777 - loss: 0.0597 - val_accuracy: 0.9134 - val_loss: 0.3403
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9844 - loss: 0.0360 - val_accuracy: 0.9091 - val_loss: 0.3637
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 773ms/step - accuracy: 0.9799 - loss: 0.0543 - val_accuracy: 0.9286 - val_loss: 0.2547
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9219 - loss: 0.2557 - val_accuracy: 0.9307 - val_loss: 0.2603

# %%
model.save('gender_detection.keras')

# %%
# plot training/validation loss/accuracy
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")

plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")

# save plot to disk
plt.savefig('plot.png')
